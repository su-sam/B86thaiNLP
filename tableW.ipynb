# %%
import pandas as pd

# %%
from pandas import DataFrame, read_csv

# %%
import csv

# %%
with open(r'C:\Users\Sumonwan\Desktop\Project\newCol.csv',encoding='utf-8') as csvfile
    df = csv.reader(csvfile, delimiter=',')
    for j in df:
        print (j)
# Out:
#   File "<ipython-input-91-99fefb8e2415>", line 1
#     with open(r'C:\Users\Sumonwan\Desktop\Project\newCol.csv',encoding='utf-8') as csvfile
#                                                                                           ^
# SyntaxError: invalid syntax

# %%
df = pd.read_csv(r'C:\Users\Sumonwan\Desktop\Project\newCol.csv');df
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, ลำคอ, ย้อย, มาก, ด, หน้าขา, แล้ว, หลัง, ใบหู, เพื่อ, แมลง, ง่า, ปลาย, แคบ, ), hand, ครั้ง, widespread, ใหม่, ทุเลา, เมื่อย, เดือน, ทั่วไป, เรื่อง, ติดตาม, ให้การ, eczema, ง่, ตุ่, feet, Eczema, +, แร้, ราว, ลด, เจ้า, นระ, ข้อศอก, ปวด, ร่วง, ผู้ใหญ่, มอ, รับ, 9, FUNGUS, ที่, แขนข, ต่อ, สัปดาห์, และ, ไข้, นม, warts, ยา, /, มากกว่า, ผื่าน, แก้ม, นูน, ดี, ผู้, เนื้อ, เป็น, น้ำ, ลอก, จาก, ติ่งหู, สะโพก, ป, เดอืน, มนิว้, กก, ดำ, ขอ, ผน, ร่ม, ำ, ฉีดยา, เก้ด, เวลา, นมา, ง่่าม, 6, สาเหตุ, การ, นัด, Lab, ได้, เมื่อ, ป่วย, ส่ง, ทิต, แฉะ, หนา, รอบ, ดาหื, แตก, ป่าย, ต้น, บ้าง, ...]
# Index: []
#
# [0 rows x 400 columns]

# %%
#Count_Row=df.shape[1]; Count_Row
# Out:
# 400

# %%
with open(r'C:\Users\Sumonwan\Desktop\Project\newCol.csv',encoding='utf-8') as csvfile:
    df = csv.reader(csvfile, delimiter=',')
    with open(r'C:\Users\Sumonwan\Desktop\Project\outp2.csv',encoding='utf-8') as csvfile2:#for compare
        reader = csv.reader(csvfile2, delimiter=',')
        for row in reader:
            a=row #word in example
            b=len(a)
            for i in range(b):
                for j in df:
                    for k in range(len(j)):
                        if j[k] is a[i] : 
                            print(a[i],j[k])
                            print(1)
                        else: 
                            print(a[i],j[k])
                            print(0)
                    k=0
                j=0
            i=0
# Out:
# ﻿ตุ่ม
# 0
# ﻿ตุ่ม ลำคอ
# 0
# ﻿ตุ่ม ย้อย
# 0
# ﻿ตุ่ม มาก
# 0
# ﻿ตุ่ม ด
# 0
# ﻿ตุ่ม หน้าขา
# 0
# ﻿ตุ่ม แล้ว
# 0
# ﻿ตุ่ม หลัง
# 0
# ﻿ตุ่ม ใบหู
# 0
# ﻿ตุ่ม เพื่อ
# 0
# ﻿ตุ่ม แมลง
# 0
# ﻿ตุ่ม ง่า
# 0
# ﻿ตุ่ม ปลาย
# 0
# ﻿ตุ่ม แคบ
# 0
# ﻿ตุ่ม )
# 0
# ﻿ตุ่ม hand
# 0
# ﻿ตุ่ม ครั้ง
# 0
# ﻿ตุ่ม widespread
# 0
# ﻿ตุ่ม ใหม่
# 0
# ﻿ตุ่ม ทุเลา
# 0
# ﻿ตุ่ม เมื่อย
# 0
# ﻿ตุ่ม เดือน
# 0
# ﻿ตุ่ม ทั่วไป
# 0
# ﻿ตุ่ม เรื่อง
# 0
# ﻿ตุ่ม ติดตาม
# 0
# ﻿ตุ่ม ให้การ
# 0
# ﻿ตุ่ม eczema
# 0
# ﻿ตุ่ม ง่
# 0
# ﻿ตุ่ม ตุ่
# 0
# ﻿ตุ่ม feet
# 0
# ﻿ตุ่ม Eczema
# 0
# ﻿ตุ่ม +
# 0
# ﻿ตุ่ม แร้
# 0
# ﻿ตุ่ม ราว
# 0
# ﻿ตุ่ม ลด
# 0
# ﻿ตุ่ม เจ้า
# 0
# ﻿ตุ่ม นระ
# 0
# ﻿ตุ่ม ข้อศอก
# 0
# ﻿ตุ่ม ปวด
# 0
# ﻿ตุ่ม ร่วง
# 0
# ﻿ตุ่ม ผู้ใหญ่
# 0
# ﻿ตุ่ม มอ
# 0
# ﻿ตุ่ม รับ
# 0
# ﻿ตุ่ม 9
# 0
# ﻿ตุ่ม FUNGUS
# 0
# ﻿ตุ่ม ที่
# 0
# ﻿ตุ่ม แขนข
# 0
# ﻿ตุ่ม ต่อ
# 0
# ﻿ตุ่ม สัปดาห์
# 0
# ﻿ตุ่ม และ
# 0
# ﻿ตุ่ม ไข้
# 0
# ﻿ตุ่ม นม
# 0
# ﻿ตุ่ม warts
# 0
# ﻿ตุ่ม ยา
# 0
# ﻿ตุ่ม /
# 0
# ﻿ตุ่ม มากกว่า
# 0
# ﻿ตุ่ม ผื่าน
# 0
# ﻿ตุ่ม แก้ม
# 0
# ﻿ตุ่ม นูน
# 0
# ﻿ตุ่ม ดี
# 0
# ﻿ตุ่ม ผู้
# 0
# ﻿ตุ่ม เนื้อ
# 0
# ﻿ตุ่ม เป็น
# 0
# ﻿ตุ่ม น้ำ
# 0
# ﻿ตุ่ม ลอก
# 0
# ﻿ตุ่ม จาก
# 0
# ﻿ตุ่ม ติ่งหู
# 0
# ﻿ตุ่ม สะโพก
# 0
# ﻿ตุ่ม ป
# 0
# ﻿ตุ่ม เดอืน
# 0
# ﻿ตุ่ม มนิว้
# 0
# ﻿ตุ่ม กก
# 0
# ﻿ตุ่ม ดำ
# 0
# ﻿ตุ่ม ขอ
# 0
# ﻿ตุ่ม ผน
# 0
# ﻿ตุ่ม ร่ม
# 0
# ﻿ตุ่ม ำ
# 0
# ﻿ตุ่ม ฉีดยา
# 0
# ﻿ตุ่ม เก้ด
# 0
# ﻿ตุ่ม เวลา
# 0
# ﻿ตุ่ม นมา
# 0
# ﻿ตุ่ม ง่่าม
# 0
# ﻿ตุ่ม 6
# 0
# ﻿ตุ่ม สาเหตุ
# 0
# ﻿ตุ่ม การ
# 0
# ﻿ตุ่ม นัด
# 0
# ﻿ตุ่ม Lab
# 0
# ﻿ตุ่ม ได้
# 0
# ﻿ตุ่ม เมื่อ
# 0
# ﻿ตุ่ม ป่วย
# 0
# ﻿ตุ่ม ส่ง
# 0
# ﻿ตุ่ม ทิต
# 0
# ﻿ตุ่ม แฉะ
# 0
# ﻿ตุ่ม หนา
# 0
# ﻿ตุ่ม รอบ
# 0
# ﻿ตุ่ม ดาหื
# 0
# ﻿ตุ่ม แตก
# 0
# ﻿ตุ่ม ป่าย
# 0
# ﻿ตุ่ม ต้น
# 0
# ﻿ตุ่ม บ้าง
# 0
# ﻿ตุ่ม อายุ
# 0
# ﻿ตุ่ม ประวัติการ
# 0
# ﻿ตุ่ม ฟัง
# 0
# ﻿ตุ่ม เล้
# 0
# ﻿ตุ่ม ื
# 0
# ﻿ตุ่ม ตาม
# 0
# ﻿ตุ่ม ต่ำๆ
# 0
# ﻿ตุ่ม แจ้ง
# 0
# ﻿ตุ่ม keratoderma
# 0
# ﻿ตุ่ม หนัง
# 0
# ﻿ตุ่ม ลาง
# 0
# ﻿ตุ่ม ทำ
# 0
# ﻿ตุ่ม วะ
# 0
# ﻿ตุ่ม บ้าน
# 0
# ﻿ตุ่ม จาย
# 0
# ﻿ตุ่ม ยั้ง
# 0
# ﻿ตุ่ม โค
# 0
# ﻿ตุ่ม หลังค
# 0
# ﻿ตุ่ม รแย
# 0
# ﻿ตุ่ม ขุย
# 0
# ﻿ตุ่ม ผาก
# 0
# ﻿ตุ่ม ใช้
# 0
# ﻿ตุ่ม กล้าม
# 0
# ﻿ตุ่ม รักษา
# 0
# ﻿ตุ่ม 90
# 0
# ﻿ตุ่ม 1
# 0
# ﻿ตุ่ม วง
# 0
# ﻿ตุ่ม 11.20
# 0
# ﻿ตุ่ม คิ้ว
# 0
# ﻿ตุ่ม C
# 0
# ﻿ตุ่ม ฝ่ามือ
# 0
# ﻿ตุ่ม เป็นๆ
# 0
# ﻿ตุ่ม ตุ่ม
# 0
# ﻿ตุ่ม คล้่ำ
# 0
# ﻿ตุ่ม ผิด
# 0
# ﻿ตุ่ม ด้วย
# 0
# ﻿ตุ่ม ต่างๆ
# 0
# ﻿ตุ่ม แพทย์
# 0
# ﻿ตุ่ม น
# 0
# ﻿ตุ่ม เนื่องจาก
# 0
# ﻿ตุ่ม ใสๆ
# 0
# ﻿ตุ่ม dermatitis
# 0
# ﻿ตุ่ม ตึง
# 0
# ﻿ตุ่ม ขนาด
# 0
# ﻿ตุ่ม Case
# 0
# ﻿ตุ่ม เจ็บ
# 0
# ﻿ตุ่ม ว
# 0
# ﻿ตุ่ม กว่า
# 0
# ﻿ตุ่ม เป็ฯ
# 0
# ﻿ตุ่ม ครอบครัว
# 0
# ﻿ตุ่ม พร้อม
# 0
# ﻿ตุ่ม ขึน
# 0
# ﻿ตุ่ม ติด
# 0
# ﻿ตุ่ม ขึ้น
# 0
# ﻿ตุ่ม แสบ
# 0
# ﻿ตุ่ม ซอก
# 0
# ﻿ตุ่ม ลอด
# 0
# ﻿ตุ่ม ตน
# 0
# ﻿ตุ่ม ไรผม
# 0
# ﻿ตุ่ม แดงๆ
# 0
# ﻿ตุ่ม แข็ง
# 0
# ﻿ตุ่ม ใต้
# 0
# ﻿ตุ่ม เข้า
# 0
# ﻿ตุ่ม ปน
# 0
# ﻿ตุ่ม ข้อ
# 0
# ﻿ตุ่ม Scabies
# 0
# ﻿ตุ่ม ถลอก
# 0
# ﻿ตุ่ม สะ
# 0
# ﻿ตุ่ม แต่
# 0
# ﻿ตุ่ม คง
# 0
# ﻿ตุ่ม ั
# 0
# ﻿ตุ่ม อก
# 0
# ﻿ตุ่ม เนื่อง
# 0
# ﻿ตุ่ม พบ
# 0
# ﻿ตุ่ม 7
# 0
# ﻿ตุ่ม เล็กๆ
# 0
# ﻿ตุ่ม หายๆ
# 0
# ﻿ตุ่ม ราบ
# 0
# ﻿ตุ่ม ร
# 0
# ﻿ตุ่ม ร้อน
# 0
# ﻿ตุ่ม ฝ่าเท้า
# 0
# ﻿ตุ่ม ตนเอง
# 0
# ﻿ตุ่ม ข้าง
# 0
# ﻿ตุ่ม หมด
# 0
# ﻿ตุ่ม รักแร้
# 0
# ﻿ตุ่ม ตัว
# 0
# ﻿ตุ่ม อาการ
# 0
# ﻿ตุ่ม เกา
# 0
# ﻿ตุ่ม ล้ม
# 0
# ﻿ตุ่ม ทาน
# 0
# ﻿ตุ่ม หนีบ
# 0
# ﻿ตุ่ม ชาว
# 0
# ﻿ตุ่ม พิการ
# 0
# ﻿ตุ่ม วัน
# 0
# ﻿ตุ่ม ร่วม
# 0
# ﻿ตุ่ม เข่า
# 0
# ﻿ตุ่ม บวม
# 0
# ﻿ตุ่ม เท้า
# 0
# ﻿ตุ่ม หน้าอก
# 0
# ﻿ตุ่ม ปรึกษา
# 0
# ﻿ตุ่ม เล็ก
# 0
# ﻿ตุ่ม มือ
# 0
# ﻿ตุ่ม 3
# 0
# ﻿ตุ่ม กน้อย
# 0
# ﻿ตุ่ม 20
# 0
# ﻿ตุ่ม Palmoplanta
# 0
# ﻿ตุ่ม ท้อง
# 0
# ﻿ตุ่ม เหนือ
# 0
# ﻿ตุ่ม เดืน
# 0
# ﻿ตุ่ม -
# 0
# ﻿ตุ่ม เต้า
# 0
# ﻿ตุ่ม ด้าน
# 0
# ﻿ตุ่ม เ
# 0
# ﻿ตุ่ม ลดลง
# 0
# ﻿ตุ่ม keratosis
# 0
# ﻿ตุ่ม จี้
# 0
# ﻿ตุ่ม 15
# 0
# ﻿ตุ่ม เหงื่อ
# 0
# ﻿ตุ่ม ทม
# 0
# ﻿ตุ่ม กระจาย
# 0
# ﻿ตุ่ม ญาติ
# 0
# ﻿ตุ่ม แดง
# 0
# ﻿ตุ่ม คาง
# 0
# ﻿ตุ่ม กลาง
# 0
# ﻿ตุ่ม คัก
# 0
# ﻿ตุ่ม อยู่
# 0
# ﻿ตุ่ม ขาว
# 0
# ﻿ตุ่ม น้อย
# 0
# ﻿ตุ่ม ชัด
# 0
# ﻿ตุ่ม ทอง
# 0
# ﻿ตุ่ม ช่วง
# 0
# ﻿ตุ่ม H
# 0
# ﻿ตุ่ม ยุบ
# 0
# ﻿ตุ่ม ซึม
# 0
# ﻿ตุ่ม มา
# 0
# ﻿ตุ่ม ขอบ
# 0
# ﻿ตุ่ม OPD
# 0
# ﻿ตุ่ม เดิม
# 0
# ﻿ตุ่ม คืน
# 0
# ﻿ตุ่ม บุตร
# 0
# ﻿ตุ่ม E
# 0
# ﻿ตุ่ม ผื่น
# 0
# ﻿ตุ่ม อา
# 0
# ﻿ตุ่ม ผล
# 0
# ﻿ตุ่ม ปี
# 0
# ﻿ตุ่ม แทน
# 0
# ﻿ตุ่ม โรค
# 0
# ﻿ตุ่ม ตรวจ
# 0
# ﻿ตุ่ม ประวัติ
# 0
# ﻿ตุ่ม นุน
# 0
# ﻿ตุ่ม เพศ
# 0
# ﻿ตุ่ม เริ่ม
# 0
# ﻿ตุ่ม ชา
# 0
# ﻿ตุ่ม ปฏิบัติ
# 0
# ﻿ตุ่ม wk
# 0
# ﻿ตุ่ม เห่อ
# 0
# ﻿ตุ่ม ยื
# 0
# ﻿ตุ่ม KOH
# 0
# ﻿ตุ่ม นิ้ว
# 0
# ﻿ตุ่ม Vitiligo
# 0
# ﻿ตุ่ม 5
# 0
# ﻿ตุ่ม น้่ำ
# 0
# ﻿ตุ่ม ทายา
# 0
# ﻿ตุ่ม IM
# 0
# ﻿ตุ่ม มี
# 0
# ﻿ตุ่ม scabies
# 0
# ﻿ตุ่ม รอย
# 0
# ﻿ตุ่ม case
# 0
# ﻿ตุ่ม ใบ
# 0
# ﻿ตุ่ม ง่าม
# 0
# ﻿ตุ่ม รร
# 0
# ﻿ตุ่ม สะเก็ด
# 0
# ﻿ตุ่ม ตลอด
# 0
# ﻿ตุ่ม or
# 0
# ﻿ตุ่ม รัก
# 0
# ﻿ตุ่ม 8
# 0
# ﻿ตุ่ม หน้าที่
# 0
# ﻿ตุ่ม ไฟฟ้า
# 0
# ﻿ตุ่ม สูง
# 0
# ﻿ตุ่ม ชาย
# 0
# ﻿ตุ่ม scabie
# 0
# ﻿ตุ่ม า
# 0
# ﻿ตุ่ม ะ
# 0
# ﻿ตุ่ม ไต่
# 0
# ﻿ตุ่ม ยัง
# 0
# ﻿ตุ่ม seborrhoeic
# 0
# ﻿ตุ่ม ไม่
# 0
# ﻿ตุ่ม 2
# 0
# ﻿ตุ่ม ที่้่
# 0
# ﻿ตุ่ม นี้
# 0
# ﻿ตุ่ม ขาอ่อน
# 0
# ﻿ตุ่ม 2wk
# 0
# ﻿ตุ่ม เหมือน
# 0
# ﻿ตุ่ม เอว
# 0
# ﻿ตุ่ม ว่า
# 0
# ﻿ตุ่ม กระ
# 0
# ﻿ตุ่ม มนิ้ว
# 0
# ﻿ตุ่ม ประปราย
# 0
# ﻿ตุ่ม opd
# 0
# ﻿ตุ่ม ตาบอด
# 0
# ﻿ตุ่ม บริ
# 0
# ﻿ตุ่ม ถล
# 0
# ﻿ตุ่ม ร้ก
# 0
# ﻿ตุ่ม พับ
# 0
# ﻿ตุ่ม ส้น
# 0
# ﻿ตุ่ม ให้
# 0
# ﻿ตุ่ม บทั่ว
# 0
# ﻿ตุ่ม จมูก
# 0
# ﻿ตุ่ม (
# 0
# ﻿ตุ่ม ขา
# 0
# ﻿ตุ่ม ก้น
# 0
# ﻿ตุ่ม ไหม
# 0
# ﻿ตุ่ม สีข
# 0
# ﻿ตุ่ม ไอ
# 0
# ﻿ตุ่ม กิน
# 0
# ﻿ตุ่ม คอ
# 0
# ﻿ตุ่ม แผล
# 0
# ﻿ตุ่ม ใบหน้า
# 0
# ﻿ตุ่ม ใน
# 0
# ﻿ตุ่ม ถุง
# 0
# ﻿ตุ่ม เขน
# 0
# ﻿ตุ่ม เวร
# 0
# ﻿ตุ่ม ก็
# 0
# ﻿ตุ่ม เปลือก
# 0
# ﻿ตุ่ม ดูแล
# 0
# ﻿ตุ่ม เท้ม
# 0
# ﻿ตุ่ม แผ่น
# 0
# ﻿ตุ่ม ขอรับ
# 0
# ﻿ตุ่ม ออก
# 0
# ﻿ตุ่ม ผ้่า
# 0
# ﻿ตุ่ม ใกล้
# 0
# ﻿ตุ่ม ใส
# 0
# ﻿ตุ่ม ขวา
# 0
# ﻿ตุ่ม ลาม
# 0
# ﻿ตุ่ม เป้
# 0
# ﻿ตุ่ม อากาศ
# 0
# ﻿ตุ่ม ซ้าย
# 0
# ﻿ตุ่ม หู
# 0
# ﻿ตุ่ม ดู
# 0
# ﻿ตุ่ม หัว
# 0
# ﻿ตุ่ม ตัด
# 0
# ﻿ตุ่ม รูป
# 0
# ﻿ตุ่ม แห้ง
# 0
# ﻿ตุ่ม เหลือง
# 0
# ﻿ตุ่ม จ
# 0
# ﻿ตุ่ม ตก
# 0
# ﻿ตุ่ม นุ
# 0
# ﻿ตุ่ม แขน
# 0
# ﻿ตุ่ม ลง
# 0
# ﻿ตุ่ม หยาบ
# 0
# ﻿ตุ่ม พี่
# 0
# ﻿ตุ่ม %
# 0
# ﻿ตุ่ม เด็ก
# 0
# ﻿ตุ่ม อวัยวะ
# 0
# ﻿ตุ่ม ไป
# 0
# ﻿ตุ่ม คล้ำ
# 0
# ﻿ตุ่ม มนิว
# 0
# ﻿ตุ่ม ผม
# 0
# ﻿ตุ่ม แข้ง
# 0
# ﻿ตุ่ม บาง
# 0
# ﻿ตุ่ม ร่มผ้า
# 0
# ﻿ตุ่ม ข
# 0
# ﻿ตุ่ม ตา
# 0
# ﻿ตุ่ม สวัป
# 0
# ﻿ตุ่ม ผืน
# 0
# ﻿ตุ่ม อัณฑะ
# 0
# ﻿ตุ่ม ไม่มี
# 0
# ﻿ตุ่ม อ
# 0
# ﻿ตุ่ม 4
# 0
# ﻿ตุ่ม อาทิตย์
# 0
# ﻿ตุ่ม หนอง
# 0
# ﻿ตุ่ม เดื่อ
# 0
# ﻿ตุ่ม หน้า
# 0
# ﻿ตุ่ม คน
# 0
# ﻿ตุ่ม สะดือ
# 0
# ﻿ตุ่ม ตั้ว
# 0
# ﻿ตุ่ม เย็น
# 0
# ﻿ตุ่ม .
# 0
# ﻿ตุ่ม บริเวณ
# 0
# ﻿ตุ่ม CPM
# 0
# ﻿ตุ่ม ก่อน
# 0
# ﻿ตุ่ม ที
# 0
# ﻿ตุ่ม ลำ
# 0
# ﻿ตุ่ม คัน
# 0
# ﻿ตุ่ม ทั่ว
# 0
# ﻿ตุ่ม ระหว่าง
# 0
# ﻿ตุ่ม ท้ายทอย
# 0
# ﻿ตุ่ม น้อง
# 0
# ﻿ตุ่ม 10
# 0
# ﻿ตุ่ม รถ
# 0
# ﻿ตุ่ม ศีรษะ
# 0
# ﻿ตุ่ม คนใน
# 0
# ﻿ตุ่ม งาม
# 0
# ﻿ตุ่ม นๆ
# 0
# ﻿ตุ่ม S
# 0
# ﻿ตุ่ม สาว
# 0
# ﻿ตุ่ม มารดา
# 0
# ﻿ตุ่ม ยกเว้น
# 0
# ﻿ตุ่ม 45
# 0
# ﻿ตุ่ม
# 0
